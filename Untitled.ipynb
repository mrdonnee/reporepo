# %%
import pandas as pd

# %%
taxis = pd.read_csv("nyc_taxis.csv", encoding="latin-1")

# %%
taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89560 entries, 0 to 89559
# Data columns (total 15 columns):
# pickup_year              89560 non-null int64
# pickup_month             89560 non-null int64
# pickup_day               89560 non-null int64
# pickup_dayofweek         89560 non-null int64
# pickup_time              89560 non-null int64
# pickup_location_code     89560 non-null int64
# dropoff_location_code    89560 non-null int64
# trip_distance            89560 non-null float64
# trip_length              89560 non-null int64
# fare_amount              89560 non-null float64
# fees_amount              89560 non-null float64
# tolls_amount             89560 non-null float64
# tip_amount               89560 non-null float64
# total_amount             89560 non-null float64
# payment_type             89560 non-null int64
# dtypes: float64(6), int64(9)
# memory usage: 10.2 MB

# %%
taxis
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0             2016             1           1                 5            0
# 1             2016             1           1                 5            0
# 2             2016             1           1                 5            0
# 3             2016             1           1                 5            0
# 4             2016             1           1                 5            0
# 5             2016             1           1                 5            0
# 6             2016             1           1                 5            0
# 7             2016             1           1                 5            0
# 8             2016             1           1                 5            0
# 9             2016             1           1                 5            0
# 10            2016             1           1                 5            1
# ...
